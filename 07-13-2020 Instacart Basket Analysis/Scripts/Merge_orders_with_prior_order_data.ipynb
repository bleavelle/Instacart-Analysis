# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/bryanleavelle/Bootcamp/Immersion/ch 4/DD-MM-2020 Instacart Basket Analysis'

# %%
#import new orders prior csv

df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Original Data', '4', 'order_products_prior.csv'))

# %%
#import previously wrangeld orders csv

df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  hour_of_order  \
# 0         2539329        1             1                  2              8
# 1         2398795        1             2                  3              7
# 2          473747        1             3                  3             12
# 3         2254736        1             4                  4              7
# 4          431534        1             5                  4             15
# ...           ...      ...           ...                ...            ...
# 3421078   2266710   206209            10                  5             18
# 3421079   1854736   206209            11                  4             10
# 3421080    626363   206209            12                  1             12
# 3421081   2977660   206209            13                  1             12
# 3421082    272231   206209            14                  6             14
#
#          days_since_prior_order
# 0                           NaN
# ...

# %%
#merge both data sets on order_id

df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  order_day_of_week  hour_of_order  \
# 0          2539329        1             1                  2              8
# 1          2539329        1             1                  2              8
# 2          2539329        1             1                  2              8
# 3          2539329        1             1                  2              8
# 4          2539329        1             1                  2              8
# ...            ...      ...           ...                ...            ...
# 32434484   2977660   206209            13                  1             12
# 32434485   2977660   206209            13                  1             12
# 32434486   2977660   206209            13                  1             12
# 32434487   2977660   206209            13                  1             12
# 32434488   2977660   206209            13                  1             12
#
# ...

# %%
#checking merge

df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#export new file

df_merged_large.to_pickle(os.path.join(path, 'Data', 'Prepared Data','df_merged_large.pkl' ))
